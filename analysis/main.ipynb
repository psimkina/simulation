# %%
from ntuple_loader import df

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df
# Out:
#                   TotalEn  InitialMomentum  InitialX  InitialY  EnergyVector  \
# entry subentry
# 0     7         66.734433             10.0       1.0       0.0      0.363246
#       11        66.734433             10.0       1.0       0.0      0.341062
#       12        66.734433             10.0       1.0       0.0      0.599671
#       13        66.734433             10.0       1.0       0.0      2.096333
#       16        66.734433             10.0       1.0       0.0      0.680936
#       17        66.734433             10.0       1.0       0.0     57.007707
#       18        66.734433             10.0       1.0       0.0      0.328340
#       22        66.734433             10.0       1.0       0.0      5.317138
#
#                 Row  Column  EnergySmeared
# entry subentry
# 0     7         2.0     1.0    -203.868945
#       11        1.0     2.0    -254.013231
#       12        2.0     2.0    -304.577512
#       13        3.0     2.0    -303.440734
# ...
